# %% [markdown]
# # Leitura dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df = pd.read_csv('../../train.csv')
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
used_cols = []

# %%
df_test = pd.read_csv('../../test.csv')
df_test.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# ...

# %% [markdown]
# # Funções auxiliares

# %%
def plot_residuals(y_pred, y_test):
    residuals = y_pred - y_test
    
    sns.scatterplot(x=y_test.flatten(), y=residuals.flatten(), alpha=0.6)
    plt.axhline(0, color='red', linestyle='--')
    plt.xlabel("Actual House Prices")
    plt.ylabel("Residuals")
    plt.title("Residual Plot")
    plt.show()     
    
def get_X_test(df, used_cols):
    X = df[used_cols].values
    return X

def create_submission(df_test, y_pred):
    submission_df = pd.DataFrame({'Id': df_test['Id'].values, 'SalePrice': y_pred})
    return submission_df

def filter_outliers(df):
    df = df.query("`LotArea` < 100000")
    return df

# %% [markdown]
# # Split (Treino / Validação)

# %%
df_train, df_val = train_test_split(df, test_size=0.2, random_state=42)

print(f"df_train shape: {df_train.shape}")
print(f"df_val shape: {df_val.shape}")
# Out:
# df_train shape: (1168, 81)
# df_val shape: (292, 81)

# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# ## Lot Area

# %%
# Scatter plot of Lot Area
if 'LotArea' not in used_cols:
    used_cols.append('LotArea')

plt.figure(figsize=(12, 8), dpi=80)
plt.title('SalePrice x LotArea')
sns.scatterplot(data=df_train, x="LotArea", y="SalePrice")

plt.show()

# %%
print(f"Correlação entre LotArea e SalePrice é: {np.corrcoef(df_train['LotArea'], df_train['SalePrice'])[0][1]:.2f}")
# Out:
# Correlação entre LotArea e SalePrice é: 0.27

# %% [markdown]
# # Outliers

# %%
df_train = filter_outliers(df_train)
print(f"Correlação entre LotArea e SalePrice é: {np.corrcoef(df_train['LotArea'], df_train['SalePrice'])[0][1]:.2f}")
# Out:
# Correlação entre LotArea e SalePrice é: 0.37

# %% [markdown]
# # Treino

# %%
X_train = df_train[used_cols].values
y_train = df_train["SalePrice"].values


X_val = df_val[used_cols].values
y_val = df_val["SalePrice"].values

# %%
lr = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# # Validação

# %%
y_pred_val = lr.predict(X_val)

# %%
rms = sqrt(mean_squared_error(y_val, y_pred_val))
print(f"RMSE é {rms:.2f}")
# Out:
# RMSE é 83336.46

# %%
# Plot da linha
plt.figure(figsize=(8,6))
sns.scatterplot(x=df_val["LotArea"], y=df_val["SalePrice"], alpha=0.5)

x_values = np.linspace(df_val["LotArea"].min(), df_val["LotArea"].max(), 100).reshape(-1, 1)

sns.regplot(x = df_val['LotArea'], y = y_pred_val, color='red', scatter=False)

plt.xlabel("LotArea")
plt.ylabel("SalePrice")
plt.title("Linear Regression: LotArea vs SalePrice")
plt.show()

# %% [markdown]
# # Plot residual

# %%
plot_residuals(y_pred_val, y_val)

# %%
X_test = get_X_test(df_test, used_cols)
y_pred_test = lr.predict(X_test)

# %% [markdown]
# # Submissão

# %%
df = create_submission(df_test, y_pred_test)
df.to_csv('submission.csv',index=False)
df.head(10)
# Out:
#      Id      SalePrice
# 0  1461  188446.731966
# 1  1462  201871.951319
# 2  1463  199653.871600
# 3  1464  180102.285608
# 4  1465  154860.842944
# 5  1466  180213.950948
# 6  1467  169961.042406
# 7  1468  172102.986666
# 8  1469  181107.273673
# 9  1470  172092.835271

# %% [markdown]
# # Pontos-chave

# %% [markdown]
# - Criamos a primeira versão do Notebook
# - Utilizamos a regressão linear como baseline
# - Adicionamos 1 feature para predição (LotArea)
# - Removemos outliers com LotArea > 100.000
# - RMSE score de 83336.46
# - Primeiro envio: obtivemos um score de 0.41153
# - Segundo envio: obtivemos um score de 0.39921
